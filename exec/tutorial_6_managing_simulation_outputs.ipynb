# %% [markdown]
# # Tutorial 6 - Managing simulation outputs

# %% [markdown]
# In the previous tutorials we have interacted with the outputs of the simulation via the default plotting functionality. However, usually we need to access the output data to manipulate it or transfer to another software, which is the topic of this notebook.
#
# We start by building and solving our model as shown in previous notebooks:

# %%
import matplotlib.pyplot as plt
import numpy as np

import pybamm

model = pybamm.lithium_ion.SPMe()
sim = pybamm.Simulation(model)
sim.solve([0, 3600])

# %% [markdown]
# ## Accessing solution variables

# %% [markdown]
# We can now access the solved variables directly to visualise or create our own plots. We first extract the solution object:

# %%
solution = sim.solution

# %% [markdown]
# Note that the solution object is also returned when calling the `solve` method, so this can be streamlined by running

# %%
solution = sim.solve([0, 3600])

# %% [markdown]
# when solving our simulation. Once we have the solution, we can define post-processed variable for the relevant variables:

# %%
t = solution["Time [s]"]
V = solution["Voltage [V]"]

# %% [markdown]
# (for a list of all the available variables see [Tutorial 3](./tutorial-3-basic-plotting.ipynb)). These `ProcessedVariable` objects contain the datapoints for the corresponding variable, which can be accessed by calling the `entries` variable. For example, for voltage, we can call

# %%
V.entries
# Out:
# array([3.77081317, 3.77079279, 3.77077254, 3.77073231, 3.77065324,
#        3.77049952, 3.77021771, 3.76995259, 3.76947399, 3.76903603,
#        3.76863064, 3.76787865, 3.7672045 , 3.76600987, 3.76506801,
#        3.76420935, 3.76341241, 3.76266442, 3.7612911 , 3.76004184,
#        3.7588895 , 3.7578216 , 3.75682942, 3.75503565, 3.75344643,
#        3.75201702, 3.75071602, 3.74952015, 3.74841036, 3.74737186,
#        3.74546111, 3.74388578, 3.74210993, 3.74059926, 3.73914878,
#        3.73774197, 3.73636906, 3.73502304, 3.73369936, 3.73110466,
#        3.72857096, 3.7260876 , 3.72125552, 3.7171124 , 3.71309641,
#        3.70921096, 3.70545836, 3.70183936, 3.69500063, 3.688684  ,
#        3.68286921, 3.67752799, 3.67262547, 3.66396455, 3.65641393,
#        3.63864846, 3.59791633, 3.48889622, 3.17239789])

# %% [markdown]
# which correspond to the data at the times

# %%
t.entries
# Out:
# array([0.00000000e+00, 1.23792596e-02, 2.47585193e-02, 4.95170385e-02,
#        9.90340771e-02, 1.98068154e-01, 3.96136308e-01, 5.94204462e-01,
#        9.90340771e-01, 1.38647708e+00, 1.78261339e+00, 2.57488600e+00,
#        3.36715862e+00, 4.95170385e+00, 6.37779456e+00, 7.80388527e+00,
#        9.22997598e+00, 1.06560667e+01, 1.35082481e+01, 1.63604295e+01,
#        1.92126109e+01, 2.20647924e+01, 2.49169738e+01, 3.06213366e+01,
#        3.63256995e+01, 4.20300623e+01, 4.77344251e+01, 5.34387880e+01,
#        5.91431508e+01, 6.48475137e+01, 7.62562393e+01, 8.65240924e+01,
#        9.89736408e+01, 1.10178234e+02, 1.21382828e+02, 1.32587421e+02,
#        1.43792015e+02, 1.54996608e+02, 1.66201202e+02, 1.88610389e+02,
#        2.11019576e+02, 2.33428763e+02, 2.78247137e+02, 3.17930983e+02,
#        3.57614829e+02, 3.97298675e+02, 4.36982521e+02, 4.76666368e+02,
#        5.56034060e+02, 6.35401752e+02, 7.14769445e+02, 7.94137137e+02,
#        8.73504829e+02, 1.03224021e+03, 1.19097560e+03, 1.50844637e+03,
#        2.14338791e+03, 3.41327098e+03, 3.60000000e+03])

# %% [markdown]
# In addition, post-processed variables can be called at any time, which will return the interpolated value from the data above:

# %%
V([200, 400, 780, 1236])  # times in seconds
# Out:
# array([3.7298096 , 3.70895128, 3.67844618, 3.65435734])

# %% [markdown]
# ## Observing custom variables from the solution
#
# The `model.variables` dictionary contains many common simulation outputs, such as

# %%
model.variables
# Out:
# {'Time [s]': Time(0x7cd905156e082010, time, children=[], domains={}),
#  'Time [min]': Multiplication(0x7a521e1336859d11, *, children=['0.016666666666666666', 'time'], domains={}),
#  'Time [h]': Multiplication(0x306612b4d2e93021, *, children=['0.0002777777777777778', 'time'], domains={}),
#  'x [m]': SpatialVariable(-0x55dcf8d6294cbab1, x, children=[], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'x_n [m]': SpatialVariable(-0x210f38bbd95a7a18, x_n, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'x_s [m]': SpatialVariable(0x445b028f6080bc95, x_s, children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'x_p [m]': SpatialVariable(0x34a231a5ccf89379, x_p, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'r_n [m]': SpatialVariable(-0x266e906d6ac9fdfd, r_n, children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'r_p [m]': SpatialVariable(0x53ae9852e09cfc35, r_p, children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Current variable [A]': FunctionParameter(-0x46793b5f24756e4b, Current function [A], children=['time'], domains={}),
#  'Total current density [A.m-2]': Division(0x57dac4bfa0e42354, /, children=['Current function [A]', 'Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell'], domains={}),
#  'Current [A]': FunctionParameter(-0x46793b5f24756e4b, Current function [A], children=['time'], domains={}),
#  'C-rate': Division(-0x7bc654c42a970287, /, children=['Current function [A]', 'Nominal cell capacity [A.h]'], domains={}),
#  'Discharge capacity [A.h]': Variable(0x4bb6422d32dae5c2, Discharge capacity [A.h], children=[], domains={}),
#  'Throughput capacity [A.h]': Variable(-0x61bd64c218090a2, Throughput capacity [A.h], children=[], domains={}),
#  'Discharge energy [W.h]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Throughput energy [W.h]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Porosity': Concatenation(0x3e206a5adf22cef5, concatenation, children=['Negative electrode porosity', 'Separator porosity', 'Positive electrode porosity'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode porosity': FunctionParameter(-0x35047da8a8ea9c92, Negative electrode porosity, children=['x_n', 'broadcast(y)', 'broadcast(z)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode porosity': XAverage(-0x5c79b132a2e6d1c, x-average, children=['Negative electrode porosity'], domains={'primary': ['current collector']}),
#  'Separator porosity': FunctionParameter(-0x1cb892a2fe720694, Separator porosity, children=['x_s', 'broadcast(y)', 'broadcast(z)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator porosity': XAverage(-0xfad00f111280ebc, x-average, children=['Separator porosity'], domains={'primary': ['current collector']}),
#  'Positive electrode porosity': FunctionParameter(-0x4d3a26902b17ce94, Positive electrode porosity, children=['x_p', 'broadcast(y)', 'broadcast(z)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode porosity': XAverage(0x540373c4f9c41549, x-average, children=['Positive electrode porosity'], domains={'primary': ['current collector']}),
#  'Porosity change': FullBroadcast(0x3fe6ee94ee3b2e5f, broadcast, children=['0.0'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode porosity change [s-1]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode porosity change [s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Separator porosity change [s-1]': FullBroadcast(0x6a4d6b9633fcbe70, broadcast, children=['0.0'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator porosity change [s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode porosity change [s-1]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode porosity change [s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode interface utilisation variable': FullBroadcast(-0x1c67e234d37d1a64, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation variable': PrimaryBroadcast(0x5e85c2f326f44398, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative electrode interface utilisation': FullBroadcast(-0x1c67e234d37d1a64, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation': PrimaryBroadcast(0x5e85c2f326f44398, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation variable': FullBroadcast(-0x781d1b49e4a0b18f, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation variable': PrimaryBroadcast(0x5e85c2f326f44398, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation': FullBroadcast(-0x781d1b49e4a0b18f, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation': PrimaryBroadcast(0x5e85c2f326f44398, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative particle crack length [m]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle crack length [m]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative particle cracking rate [m.s-1]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle cracking rate [m.s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive particle crack length [m]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle crack length [m]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive particle cracking rate [m.s-1]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle cracking rate [m.s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode active material volume fraction': FunctionParameter(-0x427a52346db71f20, Negative electrode active material volume fraction, children=['x_n', 'broadcast(y)', 'broadcast(z)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode active material volume fraction': XAverage(0x54b90d39f586f963, x-average, children=['Negative electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Negative electrode capacity [A.h]': Multiplication(0x47308179fe517034, *, children=['0.0002777777777777778', 'yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * Maximum concentration in negative electrode [mol.m-3] * F'], domains={}),
#  'Negative particle radius': Division(0x4248e3644aba664e, /, children=['Negative particle radius [m]', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle radius [m]': FunctionParameter(0x70d48a76424468b9, Negative particle radius [m], children=['x_n'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle radius [m]': XAverage(-0x7341946692fe053f, x-average, children=['Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Negative electrode surface area to volume ratio [m-1]': Division(-0x1fb90e309679f7be, /, children=['3.0 * Negative electrode active material volume fraction', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode surface area to volume ratio [m-1]': XAverage(0x5bde6c11cd84b6fb, x-average, children=['3.0 * Negative electrode active material volume fraction / Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Negative electrode active material volume fraction change [s-1]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode active material volume fraction change [s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in negative electrode [mol]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Positive electrode active material volume fraction': FunctionParameter(0x7156d888a313910e, Positive electrode active material volume fraction, children=['x_p', 'broadcast(y)', 'broadcast(z)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode active material volume fraction': XAverage(-0x67ca65b1d9330c6c, x-average, children=['Positive electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Positive electrode capacity [A.h]': Multiplication(-0x270155596035f41c, *, children=['0.0002777777777777778', 'yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * Maximum concentration in positive electrode [mol.m-3] * F'], domains={}),
#  'Positive particle radius': Division(0x39800dc516e74b3e, /, children=['Positive particle radius [m]', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle radius [m]': FunctionParameter(0x69723a6628837296, Positive particle radius [m], children=['x_p'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle radius [m]': XAverage(-0x57a74bf7a0a05c1d, x-average, children=['Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Positive electrode surface area to volume ratio [m-1]': Division(-0x7ff216a75dfa7aad, /, children=['3.0 * Positive electrode active material volume fraction', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode surface area to volume ratio [m-1]': XAverage(-0x53cbce73505c1ece, x-average, children=['3.0 * Positive electrode active material volume fraction / Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Positive electrode active material volume fraction change [s-1]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode active material volume fraction change [s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in positive electrode [mol]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Separator pressure [Pa]': PrimaryBroadcast(0x582996c766c8cc01, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator pressure [Pa]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x6317a4195130efcf, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x582996c766c8cc01, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x42908151dab7906, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x3fb7b8b32c21f3a1, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x6317a4195130efcf, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x582996c766c8cc01, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x42908151dab7906, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x3fb7b8b32c21f3a1, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged velocity [m.s-1]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged acceleration [m.s-2]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode pressure [Pa]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode pressure [Pa]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode volume-averaged velocity [m.s-1]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode volume-averaged acceleration [m.s-2]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode pressure [Pa]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode pressure [Pa]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative particle concentration [mol.m-3]': SecondaryBroadcast(-0x7bd29b11b4385ea9, broadcast, children=['X-averaged negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration [mol.m-3]': Variable(0x51dfe2b098f4efdf, X-averaged negative particle concentration [mol.m-3], children=[], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration [mol.m-3]': PrimaryBroadcast(0x77d3ffbc75f59ef4, broadcast, children=['r-average(X-averaged negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration [mol.m-3]': RAverage(-0x7918b0f0a88629e3, r-average, children=['X-averaged negative particle concentration [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration [mol.m-3]': PrimaryBroadcast(-0x7770d2723ab63968, broadcast, children=['boundary value(X-averaged negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration [mol.m-3]': BoundaryValue(0x49471844d6b7b819, boundary value, children=['X-averaged negative particle concentration [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration [mol.m-3]': Min(0x5dd8c407085f17d9, function (min), children=['broadcast(X-averaged negative particle concentration [mol.m-3])'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration [mol.m-3]': Max(0x6d6b1d7abba1a608, function (max), children=['broadcast(X-averaged negative particle concentration [mol.m-3])'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle Minimum negative particle surface concentration [mol.m-3]': Min(-0x1760da2d67c1ad3a, function (min), children=['broadcast(boundary value(X-averaged negative particle concentration [mol.m-3]))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration [mol.m-3]': Max(-0x393757fb75fa3b76, function (max), children=['broadcast(boundary value(X-averaged negative particle concentration [mol.m-3]))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle concentration': SecondaryBroadcast(-0x41a603bd38278d48, broadcast, children=['X-averaged negative particle concentration [mol.m-3] / Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration': Division(-0x277399ad5e76954a, /, children=['X-averaged negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration': PrimaryBroadcast(-0x66ea9cffa5e7e3b, broadcast, children=['r-average(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration': Division(-0x7b5e0ef9baa25050, /, children=['r-average(X-averaged negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration': PrimaryBroadcast(0x101a35b1890ed1fd, broadcast, children=['boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration': Division(-0x6007f1e14a44259c, /, children=['boundary value(X-averaged negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration': Division(0x1ec75e9456a1ec47, /, children=['min(broadcast(X-averaged negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration': Division(0x21ce2bb38be14184, /, children=['max(broadcast(X-averaged negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface concentration': Division(-0x735653482828d65e, /, children=['min(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3])))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration': Division(-0xc08fc14d2d8533f, /, children=['max(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3])))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle stoichiometry': SecondaryBroadcast(-0x41a603bd38278d48, broadcast, children=['X-averaged negative particle concentration [mol.m-3] / Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle stoichiometry': Division(-0x277399ad5e76954a, /, children=['X-averaged negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle stoichiometry': PrimaryBroadcast(-0x66ea9cffa5e7e3b, broadcast, children=['r-average(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle stoichiometry': Division(-0x7b5e0ef9baa25050, /, children=['r-average(X-averaged negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface stoichiometry': PrimaryBroadcast(0x101a35b1890ed1fd, broadcast, children=['boundary value(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface stoichiometry': Division(-0x6007f1e14a44259c, /, children=['boundary value(X-averaged negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle stoichiometry': Division(0x1ec75e9456a1ec47, /, children=['min(broadcast(X-averaged negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle stoichiometry': Division(0x21ce2bb38be14184, /, children=['max(broadcast(X-averaged negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface stoichiometry': Division(-0x735653482828d65e, /, children=['min(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3])))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface stoichiometry': Division(-0xc08fc14d2d8533f, /, children=['max(broadcast(boundary value(X-averaged negative particle concentration [mol.m-3])))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode extent of lithiation': PrimaryBroadcast(-0x66ea9cffa5e7e3b, broadcast, children=['r-average(X-averaged negative particle concentration [mol.m-3]) / Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode extent of lithiation': Division(-0x7b5e0ef9baa25050, /, children=['r-average(X-averaged negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle concentration [mol.m-3]': SecondaryBroadcast(-0x5882ae4ef15c8eb8, broadcast, children=['X-averaged positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration [mol.m-3]': Variable(0x73f0b18d0e87e036, X-averaged positive particle concentration [mol.m-3], children=[], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration [mol.m-3]': PrimaryBroadcast(-0xda8c420309b8316, broadcast, children=['r-average(X-averaged positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration [mol.m-3]': RAverage(-0x743bb924d112e997, r-average, children=['X-averaged positive particle concentration [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration [mol.m-3]': PrimaryBroadcast(0x3b125c3425abcb84, broadcast, children=['boundary value(X-averaged positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration [mol.m-3]': BoundaryValue(0x17af667e8f1a7391, boundary value, children=['X-averaged positive particle concentration [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration [mol.m-3]': Min(0xe6802a542125de0, function (min), children=['broadcast(X-averaged positive particle concentration [mol.m-3])'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration [mol.m-3]': Max(0x29aca843c869e627, function (max), children=['broadcast(X-averaged positive particle concentration [mol.m-3])'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle Minimum positive particle surface concentration [mol.m-3]': Min(-0x5c6efc5e6043a921, function (min), children=['broadcast(boundary value(X-averaged positive particle concentration [mol.m-3]))'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration [mol.m-3]': Max(-0x7e457a2c6e7c375d, function (max), children=['broadcast(boundary value(X-averaged positive particle concentration [mol.m-3]))'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle concentration': SecondaryBroadcast(0x10070ea0c25e134c, broadcast, children=['X-averaged positive particle concentration [mol.m-3] / Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration': Division(0x1fd3335cff63c294, /, children=['X-averaged positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration': PrimaryBroadcast(0x2d002b4afe4c6434, broadcast, children=['r-average(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration': Division(-0xc4fcd3b41296f17, /, children=['r-average(X-averaged positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration': PrimaryBroadcast(0x5932e852908db3bd, broadcast, children=['boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration': Division(0x55bd3e0c72513247, /, children=['boundary value(X-averaged positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration': Division(0x6308c97d965e104e, /, children=['min(broadcast(X-averaged positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration': Division(0x2d9d7f7f9091eb12, /, children=['max(broadcast(X-averaged positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface concentration': Division(-0x744bccb186aee656, /, children=['min(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3])))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration': Division(0x41b1ec6b848d9fe2, /, children=['max(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3])))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle stoichiometry': SecondaryBroadcast(0x10070ea0c25e134c, broadcast, children=['X-averaged positive particle concentration [mol.m-3] / Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle stoichiometry': Division(0x1fd3335cff63c294, /, children=['X-averaged positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle stoichiometry': PrimaryBroadcast(0x2d002b4afe4c6434, broadcast, children=['r-average(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle stoichiometry': Division(-0xc4fcd3b41296f17, /, children=['r-average(X-averaged positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface stoichiometry': PrimaryBroadcast(0x5932e852908db3bd, broadcast, children=['boundary value(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface stoichiometry': Division(0x55bd3e0c72513247, /, children=['boundary value(X-averaged positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle stoichiometry': Division(0x6308c97d965e104e, /, children=['min(broadcast(X-averaged positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle stoichiometry': Division(0x2d9d7f7f9091eb12, /, children=['max(broadcast(X-averaged positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface stoichiometry': Division(-0x744bccb186aee656, /, children=['min(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3])))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface stoichiometry': Division(0x41b1ec6b848d9fe2, /, children=['max(broadcast(boundary value(X-averaged positive particle concentration [mol.m-3])))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode extent of lithiation': PrimaryBroadcast(0x2d002b4afe4c6434, broadcast, children=['r-average(X-averaged positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode extent of lithiation': Division(-0xc4fcd3b41296f17, /, children=['r-average(X-averaged positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Porosity times concentration [mol.m-3]': ConcatenationVariable(-0x274be8f7b4b43757, Porosity times concentration [mol.m-3], children=['Negative electrode porosity times concentration [mol.m-3]', 'Separator porosity times concentration [mol.m-3]', 'Positive electrode porosity times concentration [mol.m-3]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode porosity times concentration [mol.m-3]': Variable(0x7aba61ff229badd0, Negative electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator porosity times concentration [mol.m-3]': Variable(0x31beffd73fdae703, Separator porosity times concentration [mol.m-3], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrode porosity times concentration [mol.m-3]': Variable(-0x5048bdae8ce1250e, Positive electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Total lithium in electrolyte [mol]': Multiplication(0x76743932c624a634, *, children=['(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell', 'yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Ambient temperature [K]': FunctionParameter(0x648a63a2b771dbc9, Ambient temperature [K], children=['y', 'z', 'time'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [K]': ZAverage(-0x1695fe427ac78e7b, z-average, children=['Ambient temperature [K]'], domains={}),
#  'Cell temperature [K]': PrimaryBroadcast(0x2d5c8499d7295ad1, broadcast, children=['Ambient temperature [K]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [K]': FunctionParameter(-0x3c6f3cf8849d3ba9, Ambient temperature [K], children=['y', 'z', 'broadcast(time)'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [K]': FunctionParameter(-0x3c6f3cf8849d3ba9, Ambient temperature [K], children=['y', 'z', 'broadcast(time)'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [K]': FunctionParameter(-0x3c6f3cf8849d3ba9, Ambient temperature [K], children=['y', 'z', 'broadcast(time)'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [K]': ZAverage(0x4921da93c8eee23a, z-average, children=['Ambient temperature [K]'], domains={}),
#  'Negative electrode temperature [K]': PrimaryBroadcast(0x1c79963f021a2611, broadcast, children=['Ambient temperature [K]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [K]': FunctionParameter(-0x3c6f3cf8849d3ba9, Ambient temperature [K], children=['y', 'z', 'broadcast(time)'], domains={'primary': ['current collector']}),
#  'Separator temperature [K]': PrimaryBroadcast(0x14c4ebdc3a13e1e1, broadcast, children=['Ambient temperature [K]'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [K]': FunctionParameter(-0x3c6f3cf8849d3ba9, Ambient temperature [K], children=['y', 'z', 'broadcast(time)'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [K]': PrimaryBroadcast(0x713d456220f6c778, broadcast, children=['Ambient temperature [K]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [K]': FunctionParameter(-0x3c6f3cf8849d3ba9, Ambient temperature [K], children=['y', 'z', 'broadcast(time)'], domains={'primary': ['current collector']}),
#  'Ambient temperature [C]': Addition(-0x8e348e01b9f60a1, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [C]': Addition(0x5fcc2edf806ee41b, +, children=['-273.15', 'z-average(Ambient temperature [K])'], domains={}),
#  'Cell temperature [C]': PrimaryBroadcast(-0x66ec28592bc794c7, broadcast, children=['-273.15 + Ambient temperature [K]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [C]': Addition(0x395b766c71fb9cc, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [C]': Addition(0x395b766c71fb9cc, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [C]': Addition(0x395b766c71fb9cc, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [C]': Addition(0x375cbb584e975412, +, children=['-273.15', 'z-average(Ambient temperature [K])'], domains={}),
#  'Negative electrode temperature [C]': PrimaryBroadcast(0x75b3ec40af296f0b, broadcast, children=['-273.15 + Ambient temperature [K]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [C]': Addition(0x395b766c71fb9cc, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [C]': PrimaryBroadcast(-0x6d4252901ec89fac, broadcast, children=['-273.15 + Ambient temperature [K]'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [C]': Addition(0x395b766c71fb9cc, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [C]': PrimaryBroadcast(-0x230b6790e1fa2820, broadcast, children=['-273.15 + Ambient temperature [K]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [C]': Addition(0x395b766c71fb9cc, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Negative current collector potential [V]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative SEI concentration [mol.m-3]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative SEI concentration [mol.m-3]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Volume-averaged negative SEI concentration [mol.m-3]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Loss of lithium to negative SEI [mol]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Loss of capacity to negative SEI [A.h]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Negative electrode SEI interfacial current density [A.m-2]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode SEI interfacial current density [A.m-2]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive SEI concentration [mol.m-3]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive SEI concentration [mol.m-3]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Volume-averaged positive SEI concentration [mol.m-3]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Loss of lithium to positive SEI [mol]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Loss of capacity to positive SEI [A.h]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Positive electrode SEI interfacial current density [A.m-2]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode SEI interfacial current density [A.m-2]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative SEI on cracks concentration [mol.m-3]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative SEI on cracks concentration [mol.m-3]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Volume-averaged negative SEI on cracks concentration [mol.m-3]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Loss of lithium to negative SEI on cracks [mol]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Loss of capacity to negative SEI on cracks [A.h]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Negative electrode SEI on cracks interfacial current density [A.m-2]': FullBroadcast(-0x50f3cf4a83fcfd60, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode SEI on cracks interfacial current density [A.m-2]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive SEI on cracks concentration [mol.m-3]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive SEI on cracks concentration [mol.m-3]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Volume-averaged positive SEI on cracks concentration [mol.m-3]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Loss of lithium to positive SEI on cracks [mol]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Loss of capacity to positive SEI on cracks [A.h]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Positive electrode SEI on cracks interfacial current density [A.m-2]': FullBroadcast(0x164cdce3eadf6b75, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode SEI on cracks interfacial current density [A.m-2]': PrimaryBroadcast(-0x4feed2971a751494, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
# ...
#  'Loss of active material in negative electrode [%]': Subtraction(-0x1bdf8969341163e5, -, children=['100.0', '100.0 * 0.0002777777777777778 * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * Maximum concentration in negative electrode [mol.m-3] * F / (0.0002777777777777778 * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Maximum concentration in negative electrode [mol.m-3] * F * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell)'], domains={}),
#  'Total lithium in positive electrode [mol]': Multiplication(-0x712fd160d58a3546, *, children=['yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m]', 'Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell'], domains={}),
#  'LAM_pe [%]': Subtraction(0x5379d652b1ec6bb0, -, children=['100.0', '100.0 * 0.0002777777777777778 * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * Maximum concentration in positive electrode [mol.m-3] * F / (0.0002777777777777778 * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Maximum concentration in positive electrode [mol.m-3] * F * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell)'], domains={}),
#  'Loss of active material in positive electrode [%]': Subtraction(0x5379d652b1ec6bb0, -, children=['100.0', '100.0 * 0.0002777777777777778 * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * Maximum concentration in positive electrode [mol.m-3] * F / (0.0002777777777777778 * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Maximum concentration in positive electrode [mol.m-3] * F * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell)'], domains={}),
#  'LLI [%]': Subtraction(0x169f80ec2dab1e8e, -, children=['100.0', '100.0 * (yz-average(r-average(X-averaged negative particle concentration [mol.m-3])) * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell)'], domains={}),
#  'Loss of lithium inventory [%]': Subtraction(0x169f80ec2dab1e8e, -, children=['100.0', '100.0 * (yz-average(r-average(X-averaged negative particle concentration [mol.m-3])) * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell)'], domains={}),
#  'Loss of lithium inventory, including electrolyte [%]': Subtraction(-0x51b3cf47f027181f, -, children=['100.0', '100.0 * (yz-average(r-average(X-averaged negative particle concentration [mol.m-3])) * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + ((Negative electrode thickness [m] * yz-average(x-average(Negative electrode porosity)) + Separator thickness [m] * yz-average(x-average(Separator porosity)) + Positive electrode thickness [m] * yz-average(x-average(Positive electrode porosity))) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell)'], domains={}),
#  'Total lithium [mol]': Addition(0x23dbedb912b94cbe, +, children=['yz-average(r-average(X-averaged negative particle concentration [mol.m-3])) * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium in particles [mol]': Addition(-0x6cf0f47fecd6e331, +, children=['yz-average(r-average(X-averaged negative particle concentration [mol.m-3])) * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell', 'yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell'], domains={}),
#  'Total lithium capacity [A.h]': Multiplication(0x463b38c23378fdf1, *, children=['0.0002777777777777778', '(yz-average(r-average(X-averaged negative particle concentration [mol.m-3])) * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) * F'], domains={}),
#  'Total lithium capacity in particles [A.h]': Multiplication(-0x6c07c1e630e7359a, *, children=['0.0002777777777777778', '(yz-average(r-average(X-averaged negative particle concentration [mol.m-3])) * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell) * F'], domains={}),
#  'Total lithium lost [mol]': Subtraction(0x25e5a74a94d215ee, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + ((Negative electrode thickness [m] * yz-average(x-average(Negative electrode porosity)) + Separator thickness [m] * yz-average(x-average(Separator porosity)) + Positive electrode thickness [m] * yz-average(x-average(Positive electrode porosity))) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell', 'yz-average(r-average(X-averaged negative particle concentration [mol.m-3])) * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost from particles [mol]': Subtraction(-0x118046b53443b11b, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell', 'yz-average(r-average(X-averaged negative particle concentration [mol.m-3])) * yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell + yz-average(r-average(X-averaged positive particle concentration [mol.m-3])) * yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell'], domains={}),
#  'Total lithium lost from electrolyte [mol]': Subtraction(0x430e0d6d4ae94edf, -, children=['((Negative electrode thickness [m] * yz-average(x-average(Negative electrode porosity)) + Separator thickness [m] * yz-average(x-average(Separator porosity)) + Positive electrode thickness [m] * yz-average(x-average(Positive electrode porosity))) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * Number of electrodes connected in parallel to make a cell * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost to side reactions [mol]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={}),
#  'Total capacity lost to side reactions [A.h]': Scalar(-0x36d52a306d0c72ff, 0.0, children=[], domains={})}

# %% [markdown]
# Even if a variable has not been included in the built `pybamm.Simulation`, it can still be output if the model contains the necessary building blocks. For example, we can calculate conductance from `"Current [A]"` and `"Voltage [V]"` in the `model.variables`,
# $$
# G = \dfrac{I}{V} ,
# $$
# which produces a standard `ProcessedVariable` object.

# %%
conductance_symbol = model.variables["Current [A]"] / model.variables["Voltage [V]"]
conductance = solution.observe(conductance_symbol)
conductance

# %%
# Interpolate the solution
t = np.linspace(0, solution.t[-1], 1000)

plt.plot(t, conductance(t))
plt.xlabel("Time [s]")
plt.ylabel("Conductance [S]")
# Out:
# Text(0, 0.5, 'Conductance [S]')

# %% [markdown]
# ## Saving the simulation and output data

# %% [markdown]
# In some cases simulations might take a long time to run so it is advisable to save in your computer so it can be analysed later without re-running the simulation. You can save the whole simulation doing:

# %%
sim.save("SPMe.pkl")

# %% [markdown]
# If you now check the root directory of your notebooks you will notice that a new file called `"SPMe.pkl"` has appeared. We can load the stored simulation doing

# %%
sim2 = pybamm.load("SPMe.pkl")

# %% [markdown]
# which allows the same manipulation as the original simulation would allow

# %%
sim2.plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# Alternatively, we can just save the solution of the simulation in a similar way

# %%
sol = sim.solution
sol.save("SPMe_sol.pkl")

# %% [markdown]
# and load it in a similar way too

# %%
sol2 = pybamm.load("SPMe_sol.pkl")
sol2.plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# Another option is to just save the data for some variables

# %%
sol.save_data("sol_data.pkl", ["Current [A]", "Voltage [V]"])

# %% [markdown]
# or save it in `.csv` or `.mat` format

# %%
sol.save_data("sol_data.csv", ["Current [A]", "Voltage [V]"], to_format="csv")
# matlab needs names without spaces
sol.save_data(
    "sol_data.mat",
    ["Current [A]", "Voltage [V]"],
    to_format="matlab",
    short_names={"Current [A]": "I", "Voltage [V]": "V"},
)

# %% [markdown]
# Note that while exporting `.pkl` works for all variables, exporting to `.csv` and `.mat` only works for 0D variables (i.e. variables the do not depend on space, only on time).
#
# In this notebook we have shown how to extract and store the outputs of PyBaMM's simulations. Next, in [Tutorial 7](./tutorial-7-model-options.ipynb) we will show how to change the model options.

# %% [markdown]
# Before finishing we will remove the data files we saved so that we leave the directory as we found it

# %%
import os

os.remove("SPMe.pkl")
os.remove("SPMe_sol.pkl")
os.remove("sol_data.pkl")
os.remove("sol_data.csv")
os.remove("sol_data.mat")

# %% [markdown]
# ## References
#
# The relevant papers for this notebook are:

# %%
pybamm.print_citations()
# Out:
# [1] Joel A. E. Andersson, Joris Gillis, Greg Horn, James B. Rawlings, and Moritz Diehl. CasADi – A software framework for nonlinear optimization and optimal control. Mathematical Programming Computation, 11(1):1–36, 2019. doi:10.1007/s12532-018-0139-4.
# [2] Von DAG Bruggeman. Berechnung verschiedener physikalischer konstanten von heterogenen substanzen. i. dielektrizitätskonstanten und leitfähigkeiten der mischkörper aus isotropen substanzen. Annalen der physik, 416(7):636–664, 1935.
# [3] Charles R. Harris, K. Jarrod Millman, Stéfan J. van der Walt, Ralf Gommers, Pauli Virtanen, David Cournapeau, Eric Wieser, Julian Taylor, Sebastian Berg, Nathaniel J. Smith, and others. Array programming with NumPy. Nature, 585(7825):357–362, 2020. doi:10.1038/s41586-020-2649-2.
# [4] Alan C. Hindmarsh. The PVODE and IDA algorithms. Technical Report, Lawrence Livermore National Lab., CA (US), 2000. doi:10.2172/802599.
# [5] Alan C. Hindmarsh, Peter N. Brown, Keith E. Grant, Steven L. Lee, Radu Serban, Dan E. Shumaker, and Carol S. Woodward. SUNDIALS: Suite of nonlinear and differential/algebraic equation solvers. ACM Transactions on Mathematical Software (TOMS), 31(3):363–396, 2005. doi:10.1145/1089014.1089020.
# [6] Scott G. Marquis, Valentin Sulzer, Robert Timms, Colin P. Please, and S. Jon Chapman. An asymptotic derivation of a single particle model with electrolyte. Journal of The Electrochemical Society, 166(15):A3693–A3706, 2019. doi:10.1149/2.0341915jes.
# [7] Valentin Sulzer, Scott G. Marquis, Robert Timms, Martin Robinson, and S. Jon Chapman. Python Battery Mathematical Modelling (PyBaMM). Journal of Open Research Software, 9(1):14, 2021. doi:10.5334/jors.309.
